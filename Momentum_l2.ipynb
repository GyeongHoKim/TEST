# %%
import tensorflow as tf
import numpy as np
from functools import partial

xy = np.loadtxt("data4.csv", delimiter=",", dtype=np.float32)
x_data = xy[0:-178, 0:-1]
y_data = xy[0:-178, [-1]]
x_validation_data = xy[713:, 0:-1]
y_validation_data = xy[713:, [-1]]
n_inputs = 16
n_hidden1 = 300
n_hidden2 = 300
n_hidden3 = 300
n_hidden4 = 300
n_hidden5 = 300
n_hidden6 = 300
n_hidden7 = 300
n_hidden8 = 300
n_hidden9 = 300
n_outputs = 1
learning_rate = 0.01
momentum = 0.9
n_epochs = 20001

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
Y = tf.placeholder(tf.float32, shape=(None,1), name="Y")

my_dense_layer = partial(
    tf.layers.dense, activation=tf.nn.relu,
    kernel_regularizer=tf.contrib.layers.l2_regularizer(0.001))

with tf.name_scope("dnn"):
    hidden1 = my_dense_layer(X, n_hidden1, name="hidden1", activation = tf.nn.relu)
    hidden2 = my_dense_layer(hidden1, n_hidden2, name="hidden2")
    hidden3 = my_dense_layer(hidden2, n_hidden3, name="hidden3")
    hidden4 = my_dense_layer(hidden3, n_hidden4, name="hidden4")
    hidden5 = my_dense_layer(hidden4, n_hidden5, name="hidden5")
    hidden6 = my_dense_layer(hidden5, n_hidden6, name="hidden6")
    hidden7 = my_dense_layer(hidden6, n_hidden7, name="hidden7")
    hidden8 = my_dense_layer(hidden7, n_hidden8, name="hidden8")
    hidden9 = my_dense_layer(hidden8, n_hidden9, name="hidden9")
    logits = my_dense_layer(hidden9, n_outputs, activation = None, name="outputs")
    
with tf.name_scope("loss"):
    reg_losses = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels = Y, logits = logits)
    loss = tf.add_n([tf.reduce_mean(xentropy)] + reg_losses, name="loss")
    
with tf.name_scope("train"):
    optimizer = tf.train.MomentumOptimizer(learning_rate=learning_rate, momentum=momentum, use_nesterov=True)
    training_op = optimizer.minimize(loss)
    
with tf.name_scope("eval"):
    predicted = tf.nn.sigmoid(logits)
    correct = tf.equal(tf.round(predicted), Y)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    
init = tf.global_variables_initializer()
saver = tf.train.Saver()

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        sess.run(training_op, feed_dict={X: x_data, Y: y_data})
        acc_train = accuracy.eval(feed_dict={X: x_data, Y: y_data})
        acc_val = accuracy.eval(feed_dict={X: x_validation_data, Y: y_validation_data})
        if epoch % 200 == 0:
            print(epoch, " Train accuracy: ", acc_train, " Validation accuracy: ", acc_val)
# Out:
# 0  Train accuracy:  0.39130434  Validation accuracy:  0.3539326
# 200  Train accuracy:  0.81907433  Validation accuracy:  0.8651685
# 400  Train accuracy:  0.82468444  Validation accuracy:  0.8820225
# 600  Train accuracy:  0.83169705  Validation accuracy:  0.8820225
# 800  Train accuracy:  0.83029455  Validation accuracy:  0.8707865
# 1000  Train accuracy:  0.83730716  Validation accuracy:  0.8483146
# 1200  Train accuracy:  0.84431976  Validation accuracy:  0.85393256
# 1400  Train accuracy:  0.8569425  Validation accuracy:  0.85955054
# 1600  Train accuracy:  0.85554  Validation accuracy:  0.8483146
# 1800  Train accuracy:  0.84291726  Validation accuracy:  0.752809
# 2000  Train accuracy:  0.87096775  Validation accuracy:  0.7921348
# 2200  Train accuracy:  0.8681627  Validation accuracy:  0.83146065
# 2400  Train accuracy:  0.8401122  Validation accuracy:  0.6966292
# 2600  Train accuracy:  0.88218796  Validation accuracy:  0.8202247
# 2800  Train accuracy:  0.8681627  Validation accuracy:  0.8258427
# 3000  Train accuracy:  0.87657785  Validation accuracy:  0.8146067
# 3200  Train accuracy:  0.8934081  Validation accuracy:  0.7977528
# 3400  Train accuracy:  0.9032258  Validation accuracy:  0.78089887
# 3600  Train accuracy:  0.9032258  Validation accuracy:  0.78089887
# 3800  Train accuracy:  0.91725105  Validation accuracy:  0.752809
# 4000  Train accuracy:  0.8948107  Validation accuracy:  0.73595506
# 4200  Train accuracy:  0.92426366  Validation accuracy:  0.71910113
# 4400  Train accuracy:  0.91865355  Validation accuracy:  0.78089887
# 4600  Train accuracy:  0.8793829  Validation accuracy:  0.7977528
# 4800  Train accuracy:  0.8990182  Validation accuracy:  0.7247191
# 5000  Train accuracy:  0.9354839  Validation accuracy:  0.74157304
# 5200  Train accuracy:  0.93688637  Validation accuracy:  0.747191
# 5400  Train accuracy:  0.9270687  Validation accuracy:  0.7247191
# 5600  Train accuracy:  0.92426366  Validation accuracy:  0.8146067
# 5800  Train accuracy:  0.9396914  Validation accuracy:  0.7977528
# 6000  Train accuracy:  0.941094  Validation accuracy:  0.78651685
# 6200  Train accuracy:  0.9326788  Validation accuracy:  0.73595506
# 6400  Train accuracy:  0.92426366  Validation accuracy:  0.80898875
# 6600  Train accuracy:  0.89761573  Validation accuracy:  0.78089887
# 6800  Train accuracy:  0.8751753  Validation accuracy:  0.85955054
# 7000  Train accuracy:  0.9340814  Validation accuracy:  0.76404494
# 7200  Train accuracy:  0.9424965  Validation accuracy:  0.78651685
# 7400  Train accuracy:  0.92286116  Validation accuracy:  0.78651685
# 7600  Train accuracy:  0.93688637  Validation accuracy:  0.76404494
# 7800  Train accuracy:  0.9326788  Validation accuracy:  0.78089887
# 8000  Train accuracy:  0.9326788  Validation accuracy:  0.75842696
# 8200  Train accuracy:  0.94530153  Validation accuracy:  0.7696629
# 8400  Train accuracy:  0.9270687  Validation accuracy:  0.80898875
# 8600  Train accuracy:  0.94389904  Validation accuracy:  0.7752809
# 8800  Train accuracy:  0.9424965  Validation accuracy:  0.78089887
# 9000  Train accuracy:  0.90603083  Validation accuracy:  0.76404494
# 9200  Train accuracy:  0.9424965  Validation accuracy:  0.78089887
# 9400  Train accuracy:  0.941094  Validation accuracy:  0.7752809
# 9600  Train accuracy:  0.8934081  Validation accuracy:  0.71910113
# 9800  Train accuracy:  0.94950914  Validation accuracy:  0.78651685
# 10000  Train accuracy:  0.9396914  Validation accuracy:  0.78651685
# 10200  Train accuracy:  0.9467041  Validation accuracy:  0.7921348
# 10400  Train accuracy:  0.9467041  Validation accuracy:  0.78651685
# 10600  Train accuracy:  0.9270687  Validation accuracy:  0.7921348
# 10800  Train accuracy:  0.95091164  Validation accuracy:  0.78089887
# 11000  Train accuracy:  0.94530153  Validation accuracy:  0.78651685
# 11200  Train accuracy:  0.941094  Validation accuracy:  0.78089887
# 11400  Train accuracy:  0.94530153  Validation accuracy:  0.78089887
# 11600  Train accuracy:  0.9481066  Validation accuracy:  0.78651685
# 11800  Train accuracy:  0.94950914  Validation accuracy:  0.7752809
# 12000  Train accuracy:  0.89761573  Validation accuracy:  0.73595506
# 12200  Train accuracy:  0.95652175  Validation accuracy:  0.78651685
# 12400  Train accuracy:  0.9424965  Validation accuracy:  0.78089887
# 12600  Train accuracy:  0.93688637  Validation accuracy:  0.7752809
# 12800  Train accuracy:  0.941094  Validation accuracy:  0.78089887
# 13000  Train accuracy:  0.9340814  Validation accuracy:  0.78089887
# 13200  Train accuracy:  0.95091164  Validation accuracy:  0.7921348
# 13400  Train accuracy:  0.9467041  Validation accuracy:  0.7921348
# 13600  Train accuracy:  0.9467041  Validation accuracy:  0.7921348
# 13800  Train accuracy:  0.9551192  Validation accuracy:  0.7752809
# 14000  Train accuracy:  0.9467041  Validation accuracy:  0.7977528
# 14200  Train accuracy:  0.9424965  Validation accuracy:  0.8258427
# 14400  Train accuracy:  0.9382889  Validation accuracy:  0.752809
# 14600  Train accuracy:  0.9396914  Validation accuracy:  0.75842696
# 14800  Train accuracy:  0.9396914  Validation accuracy:  0.7752809
# 15000  Train accuracy:  0.94950914  Validation accuracy:  0.8033708
# 15200  Train accuracy:  0.9551192  Validation accuracy:  0.7921348
# 15400  Train accuracy:  0.95652175  Validation accuracy:  0.7921348
# 15600  Train accuracy:  0.95652175  Validation accuracy:  0.7977528
# 15800  Train accuracy:  0.8934081  Validation accuracy:  0.7752809
# 16000  Train accuracy:  0.9467041  Validation accuracy:  0.75842696
# 16200  Train accuracy:  0.95231414  Validation accuracy:  0.78651685
# 16400  Train accuracy:  0.88920057  Validation accuracy:  0.7752809
# 16600  Train accuracy:  0.9130435  Validation accuracy:  0.8258427
# 16800  Train accuracy:  0.92847127  Validation accuracy:  0.76404494
# 17000  Train accuracy:  0.941094  Validation accuracy:  0.7921348
# 17200  Train accuracy:  0.9382889  Validation accuracy:  0.7696629
# 17400  Train accuracy:  0.94530153  Validation accuracy:  0.76404494
# 17600  Train accuracy:  0.9326788  Validation accuracy:  0.8033708
# 17800  Train accuracy:  0.8962132  Validation accuracy:  0.78651685
# 18000  Train accuracy:  0.94389904  Validation accuracy:  0.78651685
# 18200  Train accuracy:  0.9424965  Validation accuracy:  0.75842696
# 18400  Train accuracy:  0.9354839  Validation accuracy:  0.8146067
# 18600  Train accuracy:  0.94950914  Validation accuracy:  0.7696629
# 18800  Train accuracy:  0.9424965  Validation accuracy:  0.76404494
# 19000  Train accuracy:  0.9467041  Validation accuracy:  0.7752809
# 19200  Train accuracy:  0.93688637  Validation accuracy:  0.78651685
# 19400  Train accuracy:  0.9382889  Validation accuracy:  0.7921348
# 19600  Train accuracy:  0.94950914  Validation accuracy:  0.7977528
# 19800  Train accuracy:  0.95091164  Validation accuracy:  0.78651685
# 20000  Train accuracy:  0.9481066  Validation accuracy:  0.7921348
