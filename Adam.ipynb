# %%
import tensorflow as tf
import numpy as np

xy = np.loadtxt("data4.csv", delimiter=",", dtype=np.float32)
x_data = xy[0:-178, 0:-1]
y_data = xy[0:-178, [-1]]
x_validation_data = xy[713:, 0:-1]
y_validation_data = xy[713:, [-1]]
n_inputs = 16
n_hidden1 = 300
n_hidden2 = 300
n_hidden3 = 300
n_hidden4 = 300
n_hidden5 = 300
n_hidden6 = 300
n_hidden7 = 300
n_hidden8 = 300
n_hidden9 = 300
n_outputs = 1
learning_rate = 0.001
n_epochs = 20001

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
Y = tf.placeholder(tf.float32, shape=(None,1), name="Y")

with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1", activation = tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2", activation = tf.nn.relu)
    hidden3 = tf.layers.dense(hidden2, n_hidden3, name="hidden3", activation = tf.nn.relu)
    hidden4 = tf.layers.dense(hidden3, n_hidden4, name="hidden4", activation = tf.nn.relu)
    hidden5 = tf.layers.dense(hidden4, n_hidden5, name="hidden5", activation = tf.nn.relu)
    hidden6 = tf.layers.dense(hidden5, n_hidden6, name="hidden6", activation = tf.nn.relu)
    hidden7 = tf.layers.dense(hidden6, n_hidden7, name="hidden7", activation = tf.nn.relu)
    hidden8 = tf.layers.dense(hidden7, n_hidden8, name="hidden8", activation = tf.nn.relu)
    hidden9 = tf.layers.dense(hidden8, n_hidden9, name="hidden9", activation = tf.nn.relu)
    logits = tf.layers.dense(hidden9, n_outputs, name="outputs")
     
with tf.name_scope("loss"):
    xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels = Y, logits = logits)
    loss = tf.reduce_mean(xentropy, name="loss")
    
with tf.name_scope("train"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)
    
with tf.name_scope("eval"):
    predicted = tf.nn.sigmoid(logits)
    correct = tf.equal(tf.round(predicted), Y)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    
init = tf.global_variables_initializer()
saver = tf.train.Saver()

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        sess.run(training_op, feed_dict={X: x_data, Y: y_data})
        acc_train = accuracy.eval(feed_dict={X: x_data, Y: y_data})
        acc_val = accuracy.eval(feed_dict={X: x_validation_data, Y: y_validation_data})
        if epoch % 200 == 0:
            print(epoch, " Train accuracy: ", acc_train, " Validation accuracy: ", acc_val)
# Out:
# 0  Train accuracy:  0.6086956  Validation accuracy:  0.64606744
# 200  Train accuracy:  0.8485274  Validation accuracy:  0.8707865
# 400  Train accuracy:  0.8948107  Validation accuracy:  0.752809
# 600  Train accuracy:  0.9130435  Validation accuracy:  0.7696629
# 800  Train accuracy:  0.92426366  Validation accuracy:  0.80898875
# 1000  Train accuracy:  0.9340814  Validation accuracy:  0.8033708
# 1200  Train accuracy:  0.92847127  Validation accuracy:  0.80898875
# 1400  Train accuracy:  0.94530153  Validation accuracy:  0.80898875
# 1600  Train accuracy:  0.9551192  Validation accuracy:  0.8033708
# 1800  Train accuracy:  0.9551192  Validation accuracy:  0.8033708
# 2000  Train accuracy:  0.95792425  Validation accuracy:  0.8033708
# 2200  Train accuracy:  0.95652175  Validation accuracy:  0.8033708
# 2400  Train accuracy:  0.9593268  Validation accuracy:  0.8146067
# 2600  Train accuracy:  0.9663394  Validation accuracy:  0.8146067
# 2800  Train accuracy:  0.9088359  Validation accuracy:  0.83707863
# 3000  Train accuracy:  0.9649369  Validation accuracy:  0.8258427
# 3200  Train accuracy:  0.9649369  Validation accuracy:  0.8146067
# 3400  Train accuracy:  0.9677419  Validation accuracy:  0.8146067
# 3600  Train accuracy:  0.9677419  Validation accuracy:  0.83146065
# 3800  Train accuracy:  0.9607293  Validation accuracy:  0.8146067
# 4000  Train accuracy:  0.9551192  Validation accuracy:  0.83146065
# 4200  Train accuracy:  0.9607293  Validation accuracy:  0.83146065
# 4400  Train accuracy:  0.9719495  Validation accuracy:  0.83146065
# 4600  Train accuracy:  0.9551192  Validation accuracy:  0.8146067
# 4800  Train accuracy:  0.9649369  Validation accuracy:  0.83707863
# 5000  Train accuracy:  0.96353436  Validation accuracy:  0.8258427
# 5200  Train accuracy:  0.97054696  Validation accuracy:  0.8258427
# 5400  Train accuracy:  0.9607293  Validation accuracy:  0.80898875
# 5600  Train accuracy:  0.9677419  Validation accuracy:  0.8258427
# 5800  Train accuracy:  0.9719495  Validation accuracy:  0.8202247
# 6000  Train accuracy:  0.9663394  Validation accuracy:  0.8146067
# 6200  Train accuracy:  0.9747546  Validation accuracy:  0.7921348
# 6400  Train accuracy:  0.96914446  Validation accuracy:  0.8146067
# 6600  Train accuracy:  0.9677419  Validation accuracy:  0.8202247
# 6800  Train accuracy:  0.95792425  Validation accuracy:  0.8202247
# 7000  Train accuracy:  0.9747546  Validation accuracy:  0.80898875
# 7200  Train accuracy:  0.96914446  Validation accuracy:  0.8202247
# 7400  Train accuracy:  0.9677419  Validation accuracy:  0.7977528
# 7600  Train accuracy:  0.97615707  Validation accuracy:  0.8033708
# 7800  Train accuracy:  0.96353436  Validation accuracy:  0.8146067
# 8000  Train accuracy:  0.9326788  Validation accuracy:  0.76404494
# 8200  Train accuracy:  0.9663394  Validation accuracy:  0.7696629
# 8400  Train accuracy:  0.973352  Validation accuracy:  0.752809
# 8600  Train accuracy:  0.9719495  Validation accuracy:  0.747191
# 8800  Train accuracy:  0.9663394  Validation accuracy:  0.78651685
# 9000  Train accuracy:  0.9775596  Validation accuracy:  0.78651685
# 9200  Train accuracy:  0.9719495  Validation accuracy:  0.8033708
# 9400  Train accuracy:  0.9747546  Validation accuracy:  0.8033708
# 9600  Train accuracy:  0.9747546  Validation accuracy:  0.7921348
# 9800  Train accuracy:  0.9607293  Validation accuracy:  0.80898875
# 10000  Train accuracy:  0.9789621  Validation accuracy:  0.78089887
# 10200  Train accuracy:  0.9803647  Validation accuracy:  0.7977528
# 10400  Train accuracy:  0.96914446  Validation accuracy:  0.78089887
# 10600  Train accuracy:  0.9747546  Validation accuracy:  0.8033708
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-08d4fe4517a3> in <module>()
#      55     init.run()
#      56     for epoch in range(n_epochs):
# ---> 57         sess.run(training_op, feed_dict={X: x_data, Y: y_data})
#      58         acc_train = accuracy.eval(feed_dict={X: x_data, Y: y_data})
#      59         acc_val = accuracy.eval(feed_dict={X: x_validation_data, Y: y_validation_data})
#
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:
