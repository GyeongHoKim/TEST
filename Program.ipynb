# %%
import time
import pandas as pd
import numpy as np

print("If I were a passenger in the TITANIC, did I died?")

time.sleep(1)

print("Plz tell me your class(Royal, 1st, Economy)")
Pclass = 0
while Pclass != 1. and Pclass != 2. and Pclass != 3.:
    Pclass = input()
    if Pclass == 'Royal':
        Pclass = 1.
    elif Pclass == "1st":
        Pclass = 2.
    elif Pclass == "Economy":
        Pclass == 3.
    else:
        print("Plz type again")
        
print("Plz tell me your sex(male, female)")
Sex = 2.
while Sex != 1. and Sex != 0.:
    Sex = input()
    if Sex == "male":
        Sex = 0.
    elif Sex == "female":
        Sex = 1.
    else:
        print("Plz type again")
        
print("Plz tell me your age(type only the number)")
Age = ""
while type(Age) != float:
    Age = input()
    Age = float(Age)

print("Plz tell me the number of your siblings or spouse to board with(type only the number)")
SibSp = ""
while type(SibSp) != float:
    SibSp = input()
    SibSp = float(SibSp)
    
print("Plz tell me the number of your parents or children to board with(type only the number)")
Parch = ""
while type(Parch) != float:
    Parch = input()
    Parch = float(Parch)

num = SibSp + Parch + 1. 
if Pclass == 1.:
    Fare = num * 30.
elif Pclass == 2.:
    Fare = num * 13.
elif Pclass == 3.:
    Fare = num * 8.

print("Plz tell me the floor of cabin that you wants to use(1~7)")
Cabin = ""
while type(Cabin) != float:
    Cabin = input()
    Cabin = float(Cabin)

df = pd.read_csv("data2.csv")
df2 = pd.DataFrame([Pclass, Sex, Age, SibSp, Parch, Fare])
df3 = pd.concat([df2,df],axis=0)
df3

# %%
a= "20"
a = float(a)
type(a)
