# %%
import pandas as pd
from sklearn.preprocessing import scale, robust_scale, minmax_scale, maxabs_scale
from matplotlib import pyplot as plt
import statistics
import numpy as np

df = pd.read_csv('train.csv')

#필요한 값 불러오기
df2 = df[['Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked', "Survived"]]

#Sex값 int로 바꾸기
df2_Sex = df2['Sex']
Sex_encoded, Sex_categories = df2_Sex.factorize()
df2['Sex']=Sex_encoded

#Embarked값 int로 바꾸기
df2_Embarked = df2['Embarked']
Embarked_encoded, Embarked_categories = df2_Embarked.factorize()
df2['Embarked']=Embarked_encoded

#Cabin에서 NaN값 중간값으로 대체(4등분해서 계층셈플링)
df2_cabin=df2["Cabin"].tolist()
c=0
for i in df2_cabin:
    i = str(i)
    if i[0]=="A":
        df2_cabin[c]=6.
    elif i[0]=="B":
        df2_cabin[c]=5.
    elif i[0]=="C":
        df2_cabin[c]=4.
    elif i[0]=="D":
        df2_cabin[c]=3.
    elif i[0]=="E":
        df2_cabin[c]=2.
    elif i[0]=="F":
        df2_cabin[c]=1.
    elif i[0]=="G":
        df2_cabin[c]=0.
    else:
        df2_cabin[c]=None
    c=c+1
df2["Cabin"] = df2_cabin
df3 = df2.sort_values(by=['Fare'],axis=0)
Q1 = df3["Cabin"].quantile(0.25)
Q2 = df3["Cabin"].quantile(0.5)
Q3 = df3["Cabin"].quantile(0.75)
Q4 = df3["Cabin"].quantile(1)
Q1_list=[]
Q2_list=[]
Q3_list=[]
Q4_list=[]
for index, row in df2.iterrows():
    if (row["Cabin"] <= Q1):
        Q1_list.append(row["Cabin"])
    elif (row["Cabin"] <= Q2):
        Q2_list.append(row["Cabin"])
    elif (row["Cabin"] <= Q3):
        Q3_list.append(row["Cabin"])
    elif (row["Cabin"] <= Q4):
        Q4_list.append(row["Cabin"])
Q1_median = statistics.median(Q1_list)
Q2_median = statistics.median(Q2_list)
Q3_median = statistics.median(Q3_list)
Q4_median = statistics.median(Q4_list)
df2["Cabin"].fillna(7., inplace=True)
for index, row in df2.iterrows():
    if (row["Cabin"] == 7.) & (index <= 222):
        df2.loc[index, 'Cabin'] = Q1_median
    elif (row["Cabin"] == 7.) & (index <= 445):
        df2.loc[index, 'Cabin'] = Q2_median
    elif (row["Cabin"] == 7.) & (index <= 668):
        df2.loc[index, 'Cabin'] = Q3_median
    elif (row["Cabin"] == 7.):
        df2.loc[index, 'Cabin'] = Q4_median

#Age에서 NaN값 중간값으로 대체(Name에서 호칭으로 계층샘플링)
df2['Name'] = df2['Name'].map(lambda x: x.split(',')[1].split('.')[0].strip())
titles = df2['Name'].unique()
df2["Age"].fillna(-1, inplace=True)
medians = dict()
for title in titles:
    median = df2.Age[(df2["Age"] != -1) & (df2["Name"] == title)].median()
    medians[title] = median
for index, row in df2.iterrows():
    if row['Age'] == -1:
        df2.loc[index, 'Age'] = medians[row['Name']]
df2.drop("Name", axis=1, inplace=True)
df2.drop("Embarked", axis=1, inplace=True)
df2
# Out:
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\pandas\core\generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# 881       3    0  33.0      0      0    7.8958    6.0         0
# 882       3    1  22.0      0      0   10.5167    6.0         0
# 883       2    0  28.0      0      0   10.5000    6.0         0
# 884       3    0  25.0      0      0    7.0500    6.0         0
# 885       3    1  39.0      0      5   29.1250    6.0         0
# 886       2    0  27.0      0      0   13.0000    6.0         0
# 887       1    1  19.0      0      0   30.0000    5.0         1
# 888       3    1  21.0      1      2   23.4500    6.0         0
# 889       1    0  26.0      0      0   30.0000    4.0         1
# 890       3    0  32.0      0      0    7.7500    6.0         0
#
# [891 rows x 8 columns]

# %%
df2["Pclass"]=minmax_scale(df2["Pclass"])
df2["Sex"]=minmax_scale(df2["Sex"])
df2["Age"]=minmax_scale(df2["Age"])
df2["SibSp"]=minmax_scale(df2["SibSp"])
df2["Parch"]=minmax_scale(df2["Parch"])
df2["Fare"]=minmax_scale(df2["Fare"])
df2["Cabin"]=minmax_scale(df2["Cabin"])
df2
# Out:
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64.
#   warnings.warn(msg, DataConversionWarning)
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# c:\users\rlaru\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#      Pclass  Sex       Age  SibSp     Parch      Fare     Cabin  Survived
# 0       1.0  0.0  0.271174  0.125  0.000000  0.014151  0.333333         0
# 1       0.0  1.0  0.472229  0.125  0.000000  0.139136  0.666667         1
# 2       1.0  1.0  0.321438  0.000  0.000000  0.015469  0.333333         1
# 3       0.0  1.0  0.434531  0.125  0.000000  0.103644  0.666667         1
# 4       1.0  0.0  0.434531  0.000  0.000000  0.015713  0.333333         0
# 5       1.0  0.0  0.371701  0.000  0.000000  0.016510  0.333333         0
# 6       0.0  0.0  0.673285  0.000  0.000000  0.101229  0.333333         0
# 7       1.0  0.0  0.019854  0.375  0.166667  0.041136  0.333333         0
# 8       1.0  1.0  0.334004  0.000  0.333333  0.021731  0.333333         1
# 9       0.5  1.0  0.170646  0.125  0.000000  0.058694  0.333333         1
# 10      1.0  1.0  0.044986  0.125  0.166667  0.032596  0.000000         1
# 11      0.0  1.0  0.723549  0.000  0.000000  0.051822  0.666667         1
# 12      1.0  0.0  0.246042  0.000  0.000000  0.015713  0.333333         0
# 13      1.0  0.0  0.484795  0.125  0.833333  0.061045  0.333333         0
# 14      1.0  1.0  0.170646  0.000  0.000000  0.015330  0.333333         0
# 15      0.5  1.0  0.685851  0.000  0.000000  0.031230  0.333333         1
# 16      1.0  0.0  0.019854  0.500  0.166667  0.056848  0.333333         0
# 17      0.5  0.0  0.371701  0.000  0.000000  0.025374  0.333333         1
# 18      1.0  1.0  0.384267  0.125  0.000000  0.035134  0.333333         0
# 19      1.0  1.0  0.434531  0.000  0.000000  0.014102  0.333333         1
# 20      0.5  0.0  0.434531  0.000  0.000000  0.050749  0.333333         0
# 21      0.5  0.0  0.421965  0.000  0.000000  0.025374  0.500000         1
# 22      1.0  1.0  0.183212  0.000  0.000000  0.015672  0.333333         1
# 23      0.0  0.0  0.346569  0.000  0.000000  0.069291  1.000000         1
# 24      1.0  1.0  0.095250  0.375  0.166667  0.041136  0.333333         0
# 25      1.0  1.0  0.472229  0.125  0.833333  0.061264  0.333333         1
# 26      1.0  0.0  0.371701  0.000  0.000000  0.014102  0.333333         0
# 27      0.0  0.0  0.233476  0.375  0.333333  0.513342  0.666667         0
# 28      1.0  1.0  0.258608  0.000  0.000000  0.015379  0.333333         1
# 29      1.0  0.0  0.371701  0.000  0.000000  0.015412  0.333333         0
# ..      ...  ...       ...    ...       ...       ...       ...       ...
# 861     0.5  0.0  0.258608  0.125  0.000000  0.022447  1.000000         0
# 862     0.0  1.0  0.597889  0.000  0.000000  0.050610  0.500000         1
# 863     1.0  1.0  0.258608  1.000  0.333333  0.135753  1.000000         0
# 864     0.5  0.0  0.296306  0.000  0.000000  0.025374  1.000000         0
# 865     0.5  1.0  0.522493  0.000  0.000000  0.025374  1.000000         1
# 866     0.5  1.0  0.334004  0.125  0.000000  0.027050  1.000000         1
# 867     0.0  0.0  0.384267  0.000  0.000000  0.098561  1.000000         0
# 868     1.0  0.0  0.371701  0.000  0.000000  0.018543  1.000000         0
# 869     1.0  0.0  0.044986  0.125  0.166667  0.021731  1.000000         1
# 870     1.0  0.0  0.321438  0.000  0.000000  0.015412  1.000000         0
# 871     0.0  1.0  0.585323  0.125  0.166667  0.102579  0.500000         1
# 872     0.0  0.0  0.409399  0.000  0.000000  0.009759  0.833333         0
# 873     1.0  0.0  0.585323  0.000  0.000000  0.017567  1.000000         0
# 874     0.5  1.0  0.346569  0.125  0.000000  0.046845  1.000000         1
# 875     1.0  1.0  0.183212  0.000  0.000000  0.014102  1.000000         1
# 876     1.0  0.0  0.246042  0.000  0.000000  0.019218  1.000000         0
# 877     1.0  0.0  0.233476  0.000  0.000000  0.015412  1.000000         0
# 878     1.0  0.0  0.371701  0.000  0.000000  0.015412  1.000000         0
# 879     0.0  1.0  0.698417  0.000  0.166667  0.162314  0.666667         1
# 880     0.5  1.0  0.308872  0.000  0.166667  0.050749  1.000000         1
# 881     1.0  0.0  0.409399  0.000  0.000000  0.015412  1.000000         0
# 882     1.0  1.0  0.271174  0.000  0.000000  0.020527  1.000000         0
# 883     0.5  0.0  0.346569  0.000  0.000000  0.020495  1.000000         0
# 884     1.0  0.0  0.308872  0.000  0.000000  0.013761  1.000000         0
# 885     1.0  1.0  0.484795  0.000  0.833333  0.056848  1.000000         0
# 886     0.5  0.0  0.334004  0.000  0.000000  0.025374  1.000000         0
# 887     0.0  1.0  0.233476  0.000  0.000000  0.058556  0.833333         1
# 888     1.0  1.0  0.258608  0.125  0.333333  0.045771  1.000000         0
# 889     0.0  0.0  0.321438  0.000  0.000000  0.058556  0.666667         1
# 890     1.0  0.0  0.396833  0.000  0.000000  0.015127  1.000000         0
#
# [891 rows x 8 columns]

# %%
df2.to_csv("programtrain.csv")

# %%
# Out:
# float

# %%
# Out:
# True
